# %% [markdown]
# <a href="https://colab.research.google.com/github/KaterynaRb/abtests-significance-cr/blob/main/ABtests_Significance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Update the google-cloud-bigquery library for working with
# Google BigQuery if it is already installed:
# !pip install --upgrade google-cloud-bigquery
# Out:
# Requirement already satisfied: google-cloud-bigquery in /usr/local/lib/python3.12/dist-packages (3.38.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.11.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (2.25.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery) (2.38.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery) (2.7.2)
# Requirement already satisfied: packaging>=24.2.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery) (25.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery) (2.32.4)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.26.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.75.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (4.9.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.12/dist-packages (from google-resumable-media<3.0.0,>=2.0.0->google-cloud-bigquery) (1.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery) (2025.8.3)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery) (4.15.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-cloud-bigquery) (0.6.1)

# %%
# Module for working with the file system
import os

# Modules for data processing
import numpy as np
import pandas as pd
# Modules for authentication and working with BigQuery and files
from google.cloud import bigquery
from google.colab import auth, drive, files

# %%
# Authentication before working with Google Cloud
auth.authenticate_user()

# %%
# Create client for working with BigQuery,
# specifying ID of the working project in Google Cloud:
client = bigquery.Client(project="data-analytics-mate")

# %%
# Query for retrieving data from BigQuery
query = """
WITH
  session_info AS(
  SELECT
    s.date,
    s.ga_session_id,
    sp.country,
    sp.continent,
    sp.device,
    sp.channel,
    ab.test,
    ab.test_group
  FROM
    `DA.ab_test` ab
  JOIN
    `DA.session` s
  ON
    ab.ga_session_id = s.ga_session_id
  JOIN
    `DA.session_params` sp
  ON
    ab.ga_session_id = sp.ga_session_id ),
  session_with_orders AS (
  SELECT
    session_info.date,
    session_info.country,
    session_info.continent,
    session_info.device,
    session_info.channel,
    session_info.test,
    session_info.test_group,
    COUNT(DISTINCT o.ga_session_id) AS sessions_with_orders
  FROM
    `DA.order` o
  JOIN
    session_info
  ON
    o.ga_session_id = session_info.ga_session_id
  GROUP BY
    session_info.date,
    session_info.country,
    session_info.continent,
    session_info.device,
    session_info.channel,
    session_info.test,
    session_info.test_group ),
  events AS (
  SELECT
    session_info.date,
    session_info.country,
    session_info.continent,
    session_info.device,
    session_info.channel,
    session_info.test,
    session_info.test_group,
    ep.event_name,
    COUNT(ep.ga_session_id) AS event_cnt
  FROM
    `DA.event_params` ep
  JOIN
    session_info
  ON
    ep.ga_session_id = session_info.ga_session_id
  GROUP BY
    session_info.date,
    session_info.country,
    session_info.continent,
    session_info.device,
    session_info.channel,
    session_info.test,
    session_info.test_group,
    ep.event_name ),
  session AS (
  SELECT
    session_info.date,
    session_info.country,
    session_info.continent,
    session_info.device,
    session_info.channel,
    session_info.test,
    session_info.test_group,
    COUNT(DISTINCT session_info.ga_session_id) AS session_cnt
  FROM
    session_info
  GROUP BY
    session_info.date,
    session_info.country,
    session_info.continent,
    session_info.device,
    session_info.channel,
    session_info.test,
    session_info.test_group ),
  account AS (
  SELECT
    session_info.date,
    session_info.country,
    session_info.continent,
    session_info.device,
    session_info.channel,
    session_info.test,
    session_info.test_group,
    COUNT(DISTINCT acs.ga_session_id) AS new_accounts
  FROM
    `DA.account_session` acs
  JOIN
    session_info
  ON
    acs.ga_session_id = session_info.ga_session_id
  GROUP BY
    session_info.date,
    session_info.country,
    session_info.continent,
    session_info.device,
    session_info.channel,
    session_info.test,
    session_info.test_group )
SELECT
  session_with_orders.date,
  session_with_orders.country,
  session_with_orders.continent,
  session_with_orders.device,
  session_with_orders.channel,
  session_with_orders.test,
  session_with_orders.test_group,
  'sessions with orders' AS event_name,
  session_with_orders.sessions_with_orders AS value
FROM
  session_with_orders
UNION ALL
SELECT
  events.date,
  events.country,
  events.continent,
  events.device,
  events.channel,
  events.test,
  events.test_group,
  event_name,
  event_cnt AS value
FROM
  events
UNION ALL
SELECT
  session.date,
  session.country,
  session.continent,
  session.device,
  session.channel,
  session.test,
  session.test_group,
  'sessions' AS event_name,
  session_cnt AS value
FROM
  session
UNION ALL
SELECT
  account.date,
  account.country,
  account.continent,
  account.device,
  account.channel,
  account.test,
  account.test_group,
  'new accounts' AS event_name,
  new_accounts AS value
FROM
  account;
"""

query_job = client.query(query)  # Executing SQL-query
results = query_job.result()  # Waiting for the results

# %%
# Converting results of the query to DataFrame
test_results_df = results.to_dataframe()
test_results_df.head()
# Out:
#          date     country continent   device         channel  test  \
# 0  2020-11-03       Qatar      Asia  desktop  Organic Search     2
# 1  2020-11-04  Kazakhstan      Asia  desktop       Undefined     2
# 2  2020-11-04      Kuwait      Asia   mobile  Organic Search     2
# 3  2020-11-05     Georgia      Asia  desktop  Organic Search     2
# 4  2020-11-09    Slovakia    Europe  desktop  Organic Search     2
#
#    test_group            event_name  value
# 0           1  sessions with orders      1
# 1           1  sessions with orders      1
# 2           2  sessions with orders      1
# 3           1  sessions with orders      1
# 4           1  sessions with orders      1

# %%
# All events
test_results_df['event_name'].value_counts()
# Out:
# event_name
# sessions                107210
# session_start           106242
# page_view               101907
# user_engagement          94520
# first_visit              81621
# scroll                   73643
# view_promotion           61695
# view_item                44869
# sessions with orders     25892
# new accounts             22389
# view_search_results      14310
# add_shipping_info        11961
# begin_checkout           11959
# select_item              11816
# add_to_cart              11762
# select_promotion          9044
# add_payment_info          8048
# click                     1997
# view_item_list             111
# Name: count, dtype: int64

# %%
# Function calculates how many times a certain event occurred,
# returns list of values (count) for chosen metric for two groups.

def get_event_values_total(
        event: str,
        test_number: int,
        datasource: pd.DataFrame = test_results_df,
        test_col: str = 'test',
        group_col: str = 'test_group',
        event_name_col: str = 'event_name',
        event_value_col: str = 'value') -> list[int]:

    # Getting data from dataframe
    df_events = (
        datasource[(datasource[test_col] == test_number) &
                    (datasource[event_name_col] == event)]
        .groupby(group_col)[event_value_col]
        .sum()
        .reset_index())

    # Sorting by group (1 than 2) and getting only column with values
    event_values = df_events.sort_values(by=group_col).iloc[:, 1].to_list()
    return event_values

# %%
# Function calculates conversion rates for two groups and metric change.

def conversion_change(successes: list[int], trials: list[int]):
    conversion_a = successes[0] / trials[0]
    conversion_b = successes[1] / trials[1]
    metric_change = (conversion_b - conversion_a) / conversion_a

    return conversion_a, conversion_b, metric_change

# %%
# Function calculates z-statistic and statistical significance
# of results based on 5% significance level.
from statsmodels.stats.proportion import proportions_ztest

def stat_significance(successes: list[int], trials: list[int]):
    # Perform z-test
    z_stat, p_value = np.array(proportions_ztest(successes, trials),
                               dtype=np.float32)

    if p_value < 0.05:
        is_significant = True
    else:
        is_significant = False

    return z_stat, p_value, is_significant

# %%
# Function creates summary dataframe with all information
# (metrics and statistical significance):
# values of metrics, conversion rates, z-statistic and p-value.

def summary_total(
        metrics: list[str],
        num_events: list[str],
        den_events: list[str],
        datasource: pd.DataFrame = test_results_df,
        test_col: str = 'test',
        group_col: str = 'test_group',
        event_name_col: str = 'event_name',
        event_value_col: str = 'value') -> pd.DataFrame:

    # Column titles to save to a file
    column_names = ['test_number', 'metric', 'num_event', 'den_event',
         'num_count_a', 'den_count_a', 'conv_rate_a',
         'num_count_b', 'den_count_b', 'conv_rate_b',
         'metric_change', 'z_stat', 'p_value', 'significant']

    data = pd.DataFrame(columns=column_names)
    tests = sorted(datasource[test_col].unique().tolist())

    # Writing data into dataframe by rows for each test
    # and for all metrics within one test.
    for test_number in tests:
        for metric, num_event, den_event in zip(metrics, num_events, den_events):
            row = [test_number, metric, num_event, den_event]

            # Calculating numerator and denominator values
            num_event_cnt = get_event_values_total(num_event, test_number,
                                                   datasource, test_col,
                                                   group_col, event_name_col,
                                                   event_value_col)
            den_event_cnt = get_event_values_total(den_event, test_number,
                                                   datasource, test_col,
                                                   group_col, event_name_col,
                                                   event_value_col)

            # Calculating conversions for two groups and metric change
            conversion_a, conversion_b, metric_change = (
                conversion_change(num_event_cnt, den_event_cnt))

            # Writing data to row
            row.append(num_event_cnt[0])
            row.append(den_event_cnt[0])
            row.append(conversion_a)

            row.append(num_event_cnt[1])
            row.append(den_event_cnt[1])
            row.append(conversion_b)

            row.append(metric_change)

            # Perform z-test for two proportions (A and B)
            stat_signif = stat_significance(num_event_cnt, den_event_cnt)
            row.extend(stat_signif)

            # Adding row with data to result summary dataframe
            data.loc[len(data)] = row

    return(data)

# %%
# Creating summary in total for 4 metrics
metrics = ['add_payment_info / sessions', 'add_shipping_info / sessions', 'begin_checkout / sessions', 'new_accounts / sessions']
num_events = ['add_payment_info', 'add_shipping_info', 'begin_checkout', 'new accounts']
den_events = ['sessions', 'sessions', 'sessions', 'sessions']

df_summary_total = summary_total(metrics, num_events, den_events)
print(df_summary_total.to_markdown())
# Out:
# |    |   test_number | metric                       | num_event         | den_event   |   num_count_a |   den_count_a |   conv_rate_a |   num_count_b |   den_count_b |   conv_rate_b |   metric_change |    z_stat |     p_value | significant   |
# |---:|--------------:|:-----------------------------|:------------------|:------------|--------------:|--------------:|--------------:|--------------:|--------------:|--------------:|----------------:|----------:|------------:|:--------------|
# |  0 |             1 | add_payment_info / sessions  | add_payment_info  | sessions    |          1988 |         45362 |     0.0438252 |          2229 |         45193 |     0.0493218 |       0.12542   | -3.92488  | 8.67715e-05 | True          |
# |  1 |             1 | add_shipping_info / sessions | add_shipping_info | sessions    |          3034 |         45362 |     0.0668842 |          3221 |         45193 |     0.0712721 |       0.0656048 | -2.60357  | 0.0092258   | True          |
# |  2 |             1 | begin_checkout / sessions    | begin_checkout    | sessions    |          3784 |         45362 |     0.0834178 |          4021 |         45193 |     0.088974  |       0.0666059 | -2.97878  | 0.00289396  | True          |
# |  3 |             1 | new_accounts / sessions      | new accounts      | sessions    |          3823 |         45362 |     0.0842776 |          3681 |         45193 |     0.0814507 |      -0.033543  |  1.54288  | 0.122859    | False         |
# |  4 |             2 | add_payment_info / sessions  | add_payment_info  | sessions    |          2344 |         50637 |     0.0462903 |          2409 |         50244 |     0.047946  |       0.0357691 | -1.24099  | 0.214608    | False         |
# |  5 |             2 | add_shipping_info / sessions | add_shipping_info | sessions    |          3480 |         50637 |     0.0687245 |          3510 |         50244 |     0.0698591 |       0.0165099 | -0.709557 | 0.477979    | False         |
# |  6 |             2 | begin_checkout / sessions    | begin_checkout    | sessions    |          4262 |         50637 |     0.0841677 |          4313 |         50244 |     0.0858411 |       0.0198816 | -0.952898 | 0.340642    | False         |
# |  7 |             2 | new_accounts / sessions      | new accounts      | sessions    |          4165 |         50637 |     0.0822521 |          4184 |         50244 |     0.0832736 |       0.0124193 | -0.588793 | 0.556       | False         |
# |  8 |             3 | add_payment_info / sessions  | add_payment_info  | sessions    |          3623 |         70047 |     0.0517224 |          3697 |         70439 |     0.0524851 |       0.0147463 | -0.643172 | 0.520112    | False         |
# |  9 |             3 | add_shipping_info / sessions | add_shipping_info | sessions    |          5298 |         70047 |     0.0756349 |          5188 |         70439 |     0.0736524 |      -0.0262121 |  1.41373  | 0.157442    | False         |
# | 10 |             3 | begin_checkout / sessions    | begin_checkout    | sessions    |          9532 |         70047 |     0.13608   |          9264 |         70439 |     0.131518  |      -0.0335245 |  2.51139  | 0.0120257   | True          |
# | 11 |             3 | new_accounts / sessions      | new accounts      | sessions    |          5856 |         70047 |     0.083601  |          5822 |         70439 |     0.0826531 |      -0.0113388 |  0.643489 | 0.519907    | False         |
# | 12 |             4 | add_payment_info / sessions  | add_payment_info  | sessions    |          3731 |        105079 |     0.0355066 |          3601 |        105141 |     0.0342492 |      -0.0354123 |  1.57111  | 0.116158    | False         |
# | 13 |             4 | add_shipping_info / sessions | add_shipping_info | sessions    |          5128 |        105079 |     0.0488014 |          4956 |        105141 |     0.0471367 |      -0.0341112 |  1.7858   | 0.0741324   | False         |
# | 14 |             4 | begin_checkout / sessions    | begin_checkout    | sessions    |         12555 |        105079 |     0.119482  |         12267 |        105141 |     0.116672  |      -0.0235152 |  1.996    | 0.0459342   | True          |
# | 15 |             4 | new_accounts / sessions      | new accounts      | sessions    |          8984 |        105079 |     0.0854976 |          8687 |        105141 |     0.0826224 |      -0.033629  |  2.37546  | 0.0175273   | True          |

# %%
# Function calculates how many times a certain event occurred,
# but broken down by category.
# Returns dataframe with values (count) for chosen metric,
# broken down by category.

def get_event_values_breakdown(
        event: str, test_number: int,
        breakdown_by: str, datasource: pd.DataFrame = test_results_df,
        test_col: str = 'test',	group_col: str = 'test_group',
        event_name_col: str = 'event_name',
        event_value_col: str = 'value') -> pd.DataFrame:

    # Getting data from dataframe into pivot table,
    # grouped by test group and given category
    df_events = (
        pd.pivot_table(datasource[(datasource[test_col] == test_number) &
                      (datasource[event_name_col] == event)],
                       values=event_value_col,
                       index=breakdown_by,
                       columns=group_col,
                       aggfunc='sum'))

    return df_events

# %%
# Function creates summary dataframe with all information for data broken down
# by category (metrics and statistical significance):
# values of metrics, categories, conversion rates, z-statistic and p-value.

def summary_breakdown(
        metrics: list[str], num_events: list[str],
        den_events: list[str], breakdown_by: str,
        datasource: pd.DataFrame = test_results_df,
        test_col: str = 'test',	group_col: str = 'test_group',
        event_name_col: str = 'event_name',
        event_value_col: str = 'value') -> pd.DataFrame:

    # Column titles to save to a file
    column_names = ['test_number', breakdown_by,
          'metric', 'num_event', 'den_event',
          'num_count_a', 'den_count_a', 'conv_rate_a',
          'num_count_b', 'den_count_b', 'conv_rate_b',
          'metric_change', 'z_stat', 'p_value', 'significant']

    data = pd.DataFrame(columns=column_names)
    categories = datasource[breakdown_by].unique().tolist()
    tests = sorted(datasource[test_col].unique().tolist())

    # Writing data into dataframe by rows for each test
    # and for all metrics within one test, also broken down by category
    for test_number in tests:
        for metric, num_event, den_event in zip(metrics, num_events, den_events):
            for category in categories:
                row = [test_number, category, metric, num_event, den_event]

                # Calculating numerator and denominator values for given category
                num_event_cnt = (get_event_values_breakdown(num_event, test_number,
                                                           breakdown_by, datasource,
                                                           test_col, group_col,
                                                           event_name_col,
                                                           event_value_col).loc[category, :].to_list())

                den_event_cnt = get_event_values_breakdown(den_event, test_number,
                                                           breakdown_by, datasource,
                                                           test_col, group_col,
                                                           event_name_col,
                                                           event_value_col).loc[category, :].to_list()

                # Calculating conversions for two groups and metric change
                conversion_a, conversion_b, metric_change = (
                    conversion_change(num_event_cnt, den_event_cnt))

                # Writing data to row
                row.append(num_event_cnt[0])
                row.append(den_event_cnt[0])
                row.append(conversion_a)

                row.append(num_event_cnt[1])
                row.append(den_event_cnt[1])
                row.append(conversion_b)

                row.append(metric_change)

                # Perform z-test for two proportions (A and B)
                stat_signif = stat_significance(num_event_cnt, den_event_cnt)
                row.extend(stat_signif)

                # Adding row with data to result summary dataframe
                data.loc[len(data)] = row

    return data

# %%
# Creating summary of test results for 4 metrics (by continent, device and channel)
df_summary_continent = summary_breakdown(metrics, num_events, den_events, 'continent')
df_summary_device = summary_breakdown(metrics, num_events, den_events, 'device')
df_summary_channel = summary_breakdown(metrics, num_events, den_events, 'channel')

# %%
print(df_summary_continent.to_markdown())
print(df_summary_device.to_markdown())
print(df_summary_channel.to_markdown())
# Out:
# |    |   test_number | continent   | metric                       | num_event         | den_event   |   num_count_a |   den_count_a |   conv_rate_a |   num_count_b |   den_count_b |   conv_rate_b |   metric_change |      z_stat |     p_value | significant   |
# |---:|--------------:|:------------|:-----------------------------|:------------------|:------------|--------------:|--------------:|--------------:|--------------:|--------------:|--------------:|----------------:|------------:|------------:|:--------------|
# |  0 |             1 | Asia        | add_payment_info / sessions  | add_payment_info  | sessions    |           512 |         10626 |     0.0481837 |           545 |         10932 |     0.0498536 |     0.0346578   | -0.567695   | 0.570242    | False         |
# |  1 |             1 | Europe      | add_payment_info / sessions  | add_payment_info  | sessions    |           324 |          8472 |     0.0382436 |           452 |          8423 |     0.0536626 |     0.403177    | -4.78697    | 1.69318e-06 | True          |
# |  2 |             1 | Africa      | add_payment_info / sessions  | add_payment_info  | sessions    |            19 |           494 |     0.0384615 |            24 |           474 |     0.0506329 |     0.316456    | -0.918808   | 0.358196    | False         |
# |  3 |             1 | Oceania     | add_payment_info / sessions  | add_payment_info  | sessions    |            19 |           509 |     0.0373281 |            21 |           495 |     0.0424242 |     0.136523    | -0.412764   | 0.679779    | False         |
# |  4 |             1 | Americas    | add_payment_info / sessions  | add_payment_info  | sessions    |          1107 |         25164 |     0.0439914 |          1177 |         24769 |     0.0475191 |     0.0801897   | -1.88647    | 0.0592318   | False         |
# |  5 |             1 | (not set)   | add_payment_info / sessions  | add_payment_info  | sessions    |             7 |            97 |     0.0721649 |            10 |           100 |     0.1       |     0.385714    | -0.695585   | 0.486689    | False         |
# |  6 |             1 | Asia        | add_shipping_info / sessions | add_shipping_info | sessions    |           730 |         10626 |     0.0686994 |           798 |         10932 |     0.0729967 |     0.0625521   | -1.22923    | 0.218987    | False         |
# |  7 |             1 | Europe      | add_shipping_info / sessions | add_shipping_info | sessions    |           528 |          8472 |     0.0623229 |           606 |          8423 |     0.0719459 |     0.154404    | -2.49927    | 0.0124448   | True          |
# |  8 |             1 | Africa      | add_shipping_info / sessions | add_shipping_info | sessions    |            41 |           494 |     0.082996  |            28 |           474 |     0.0590717 |    -0.288258    |  1.44618    | 0.148125    | False         |
# |  9 |             1 | Oceania     | add_shipping_info / sessions | add_shipping_info | sessions    |            27 |           509 |     0.0530452 |            38 |           495 |     0.0767677 |     0.447213    | -1.52721    | 0.126708    | False         |
# | 10 |             1 | Americas    | add_shipping_info / sessions | add_shipping_info | sessions    |          1704 |         25164 |     0.0677158 |          1738 |         24769 |     0.0701684 |     0.0362186   | -1.08161    | 0.279427    | False         |
# | 11 |             1 | (not set)   | add_shipping_info / sessions | add_shipping_info | sessions    |             4 |            97 |     0.0412371 |            13 |           100 |     0.13      |     2.1525      | -2.21814    | 0.026545    | True          |
# | 12 |             1 | Asia        | begin_checkout / sessions    | begin_checkout    | sessions    |           915 |         10626 |     0.0861095 |          1002 |         10932 |     0.0916575 |     0.0644293   | -1.43081    | 0.152486    | False         |
# | 13 |             1 | Europe      | begin_checkout / sessions    | begin_checkout    | sessions    |           645 |          8472 |     0.0761331 |           744 |          8423 |     0.0883296 |     0.160199    | -2.88561    | 0.0039066   | True          |
# | 14 |             1 | Africa      | begin_checkout / sessions    | begin_checkout    | sessions    |            54 |           494 |     0.109312  |            33 |           474 |     0.0696203 |    -0.363104    |  2.15844    | 0.0308936   | True          |
# | 15 |             1 | Oceania     | begin_checkout / sessions    | begin_checkout    | sessions    |            36 |           509 |     0.0707269 |            56 |           495 |     0.113131  |     0.599551    | -2.32835    | 0.0198936   | True          |
# | 16 |             1 | Americas    | begin_checkout / sessions    | begin_checkout    | sessions    |          2130 |         25164 |     0.0846447 |          2164 |         24769 |     0.0873673 |     0.0321644   | -1.08496    | 0.27794     | False         |
# | 17 |             1 | (not set)   | begin_checkout / sessions    | begin_checkout    | sessions    |             4 |            97 |     0.0412371 |            22 |           100 |     0.22      |     4.335       | -3.70605    | 0.000210514 | True          |
# | 18 |             1 | Asia        | new_accounts / sessions      | new accounts      | sessions    |           878 |         10626 |     0.0826275 |           934 |         10932 |     0.0854372 |     0.0340048   | -0.743336   | 0.457278    | False         |
# | 19 |             1 | Europe      | new_accounts / sessions      | new accounts      | sessions    |           700 |          8472 |     0.0826251 |           683 |          8423 |     0.0810875 |    -0.0186096   |  0.36451    | 0.715477    | False         |
# | 20 |             1 | Africa      | new_accounts / sessions      | new accounts      | sessions    |            36 |           494 |     0.0728745 |            38 |           474 |     0.0801688 |     0.100094    | -0.426961   | 0.669408    | False         |
# | 21 |             1 | Oceania     | new_accounts / sessions      | new accounts      | sessions    |            37 |           509 |     0.0726916 |            44 |           495 |     0.0888889 |     0.222823    | -0.942169   | 0.346106    | False         |
# | 22 |             1 | Americas    | new_accounts / sessions      | new accounts      | sessions    |          2165 |         25164 |     0.0860356 |          1971 |         24769 |     0.0795753 |    -0.075089    |  2.61869    | 0.00882684  | True          |
# | 23 |             1 | (not set)   | new_accounts / sessions      | new accounts      | sessions    |             7 |            97 |     0.0721649 |            11 |           100 |     0.11      |     0.524286    | -0.921405   | 0.356839    | False         |
# | 24 |             2 | Asia        | add_payment_info / sessions  | add_payment_info  | sessions    |           572 |         11983 |     0.0477343 |           630 |         11983 |     0.0525745 |     0.101399    | -1.71652    | 0.0860666   | False         |
# | 25 |             2 | Europe      | add_payment_info / sessions  | add_payment_info  | sessions    |           481 |          9520 |     0.0505252 |           395 |          9318 |     0.0423911 |    -0.160992    |  2.65082    | 0.00802978  | True          |
# | 26 |             2 | Africa      | add_payment_info / sessions  | add_payment_info  | sessions    |            32 |           566 |     0.0565371 |            11 |           490 |     0.022449  |    -0.602934    |  2.79513    | 0.00518785  | True          |
# | 27 |             2 | Oceania     | add_payment_info / sessions  | add_payment_info  | sessions    |            18 |           577 |     0.0311958 |            24 |           551 |     0.0435572 |     0.396249    | -1.09608    | 0.273042    | False         |
# | 28 |             2 | Americas    | add_payment_info / sessions  | add_payment_info  | sessions    |          1230 |         27902 |     0.0440829 |          1342 |         27772 |     0.0483221 |     0.0961641   | -2.38254    | 0.0171939   | True          |
# | 29 |             2 | (not set)   | add_payment_info / sessions  | add_payment_info  | sessions    |            11 |            89 |     0.123596  |             7 |           130 |     0.0538462 |    -0.564336    |  1.84584    | 0.0649151   | False         |
# | 30 |             2 | Asia        | add_shipping_info / sessions | add_shipping_info | sessions    |           833 |         11983 |     0.0695151 |           871 |         11983 |     0.0726863 |     0.0456182   | -0.955134   | 0.33951     | False         |
# | 31 |             2 | Europe      | add_shipping_info / sessions | add_shipping_info | sessions    |           643 |          9520 |     0.067542  |           628 |          9318 |     0.0673964 |    -0.0021554   |  0.0398269  | 0.968231    | False         |
# | 32 |             2 | Africa      | add_shipping_info / sessions | add_shipping_info | sessions    |            50 |           566 |     0.0883392 |            21 |           490 |     0.0428571 |    -0.514857    |  2.94328    | 0.00324757  | True          |
# | 33 |             2 | Oceania     | add_shipping_info / sessions | add_shipping_info | sessions    |            24 |           577 |     0.0415945 |            48 |           551 |     0.0871143 |     1.09437     | -3.12623    | 0.00177062  | True          |
# | 34 |             2 | Americas    | add_shipping_info / sessions | add_shipping_info | sessions    |          1923 |         27902 |     0.0689198 |          1931 |         27772 |     0.0695305 |     0.00886061  | -0.283825   | 0.776545    | False         |
# | 35 |             2 | (not set)   | add_shipping_info / sessions | add_shipping_info | sessions    |             7 |            89 |     0.0786517 |            11 |           130 |     0.0846154 |     0.0758242   | -0.157823   | 0.874596    | False         |
# | 36 |             2 | Asia        | begin_checkout / sessions    | begin_checkout    | sessions    |          1008 |         11983 |     0.0841192 |          1102 |         11983 |     0.0919636 |     0.093254    | -2.14289    | 0.0321223   | True          |
# | 37 |             2 | Europe      | begin_checkout / sessions    | begin_checkout    | sessions    |           787 |          9520 |     0.0826681 |           742 |          9318 |     0.0796308 |    -0.0367402   |  0.763198   | 0.445345    | False         |
# | 38 |             2 | Africa      | begin_checkout / sessions    | begin_checkout    | sessions    |            64 |           566 |     0.113074  |            25 |           490 |     0.0510204 |    -0.548788    |  3.61991    | 0.0002947   | True          |
# | 39 |             2 | Oceania     | begin_checkout / sessions    | begin_checkout    | sessions    |            34 |           577 |     0.0589255 |            65 |           551 |     0.117967  |     1.00198     | -3.5031     | 0.000459871 | True          |
# | 40 |             2 | Americas    | begin_checkout / sessions    | begin_checkout    | sessions    |          2361 |         27902 |     0.0846176 |          2360 |         27772 |     0.0849777 |     0.00425544  | -0.152493   | 0.878798    | False         |
# | 41 |             2 | (not set)   | begin_checkout / sessions    | begin_checkout    | sessions    |             8 |            89 |     0.0898876 |            19 |           130 |     0.146154  |     0.625962    | -1.24395    | 0.213517    | False         |
# | 42 |             2 | Asia        | new_accounts / sessions      | new accounts      | sessions    |           985 |         11983 |     0.0821998 |          1025 |         11983 |     0.0855378 |     0.0406091   | -0.932144   | 0.351262    | False         |
# | 43 |             2 | Europe      | new_accounts / sessions      | new accounts      | sessions    |           770 |          9520 |     0.0808824 |           771 |          9318 |     0.0827431 |     0.0230053   | -0.4659     | 0.641287    | False         |
# | 44 |             2 | Africa      | new_accounts / sessions      | new accounts      | sessions    |            47 |           566 |     0.0830389 |            37 |           490 |     0.0755102 |    -0.0906644   |  0.450903   | 0.652059    | False         |
# | 45 |             2 | Oceania     | new_accounts / sessions      | new accounts      | sessions    |            48 |           577 |     0.0831889 |            44 |           551 |     0.0798548 |    -0.0400786   |  0.204514   | 0.837952    | False         |
# | 46 |             2 | Americas    | new_accounts / sessions      | new accounts      | sessions    |          2307 |         27902 |     0.0826822 |          2296 |         27772 |     0.0826732 |    -0.000109443 |  0.00387649 | 0.996907    | False         |
# | 47 |             2 | (not set)   | new_accounts / sessions      | new accounts      | sessions    |             8 |            89 |     0.0898876 |            11 |           130 |     0.0846154 |    -0.0586538   |  0.136142   | 0.891709    | False         |
# | 48 |             3 | Asia        | add_payment_info / sessions  | add_payment_info  | sessions    |           872 |         16628 |     0.0524417 |           843 |         16715 |     0.0504337 |    -0.0382887   |  0.829955   | 0.406564    | False         |
# | 49 |             3 | Europe      | add_payment_info / sessions  | add_payment_info  | sessions    |           681 |         13190 |     0.05163   |           710 |         13108 |     0.0541654 |     0.0491066   | -0.91848    | 0.358368    | False         |
# | 50 |             3 | Africa      | add_payment_info / sessions  | add_payment_info  | sessions    |            33 |           681 |     0.0484581 |            28 |           709 |     0.0394922 |    -0.185024    |  0.815776   | 0.414628    | False         |
# | 51 |             3 | Oceania     | add_payment_info / sessions  | add_payment_info  | sessions    |            64 |           684 |     0.0935673 |            56 |           763 |     0.0733945 |    -0.215596    |  1.3892     | 0.164773    | False         |
# | 52 |             3 | Americas    | add_payment_info / sessions  | add_payment_info  | sessions    |          1959 |         38689 |     0.0506345 |          2041 |         38992 |     0.0523441 |     0.033762    | -1.07797    | 0.281048    | False         |
# | 53 |             3 | (not set)   | add_payment_info / sessions  | add_payment_info  | sessions    |            14 |           175 |     0.08      |            19 |           152 |     0.125     |     0.5625      | -1.3474     | 0.177851    | False         |
# | 54 |             3 | Asia        | add_shipping_info / sessions | add_shipping_info | sessions    |          1213 |         16628 |     0.0729492 |          1184 |         16715 |     0.0708346 |    -0.0289881   |  0.747447   | 0.454794    | False         |
# | 55 |             3 | Europe      | add_shipping_info / sessions | add_shipping_info | sessions    |          1003 |         13190 |     0.0760425 |           999 |         13108 |     0.076213  |     0.00224274  | -0.0521419  | 0.958416    | False         |
# | 56 |             3 | Africa      | add_shipping_info / sessions | add_shipping_info | sessions    |            48 |           681 |     0.0704846 |            51 |           709 |     0.0719323 |     0.0205395   | -0.104908   | 0.916449    | False         |
# | 57 |             3 | Oceania     | add_shipping_info / sessions | add_shipping_info | sessions    |            85 |           684 |     0.124269  |            80 |           763 |     0.104849  |    -0.156272    |  1.16033    | 0.245914    | False         |
# | 58 |             3 | Americas    | add_shipping_info / sessions | add_shipping_info | sessions    |          2925 |         38689 |     0.0756029 |          2854 |         38992 |     0.0731945 |    -0.0318557   |  1.27899    | 0.2009      | False         |
# | 59 |             3 | (not set)   | add_shipping_info / sessions | add_shipping_info | sessions    |            24 |           175 |     0.137143  |            20 |           152 |     0.131579  |    -0.0405702   |  0.147053   | 0.88309     | False         |
# | 60 |             3 | Asia        | begin_checkout / sessions    | begin_checkout    | sessions    |          2162 |         16628 |     0.130022  |          2119 |         16715 |     0.126772  |    -0.0249904   |  0.886806   | 0.375183    | False         |
# | 61 |             3 | Europe      | begin_checkout / sessions    | begin_checkout    | sessions    |          1777 |         13190 |     0.134723  |          1784 |         13108 |     0.1361    |     0.0102196   | -0.326269   | 0.744221    | False         |
# | 62 |             3 | Africa      | begin_checkout / sessions    | begin_checkout    | sessions    |            80 |           681 |     0.117474  |            91 |           709 |     0.12835   |     0.0925776   | -0.617096   | 0.537171    | False         |
# | 63 |             3 | Oceania     | begin_checkout / sessions    | begin_checkout    | sessions    |           160 |           684 |     0.233918  |           147 |           763 |     0.192661  |    -0.176376    |  1.91649    | 0.0553027   | False         |
# | 64 |             3 | Americas    | begin_checkout / sessions    | begin_checkout    | sessions    |          5309 |         38689 |     0.137222  |          5089 |         38992 |     0.130514  |    -0.0488879   |  2.7456     | 0.00603998  | True          |
# | 65 |             3 | (not set)   | begin_checkout / sessions    | begin_checkout    | sessions    |            44 |           175 |     0.251429  |            34 |           152 |     0.223684  |    -0.110347    |  0.587141   | 0.557109    | False         |
# | 66 |             3 | Asia        | new_accounts / sessions      | new accounts      | sessions    |          1443 |         16628 |     0.0867813 |          1395 |         16715 |     0.083458  |    -0.0382958   |  1.08733    | 0.276891    | False         |
# | 67 |             3 | Europe      | new_accounts / sessions      | new accounts      | sessions    |          1086 |         13190 |     0.0823351 |          1106 |         13108 |     0.084376  |     0.0247871   | -0.59866    | 0.549399    | False         |
# | 68 |             3 | Africa      | new_accounts / sessions      | new accounts      | sessions    |            46 |           681 |     0.0675477 |            43 |           709 |     0.0606488 |    -0.102134    |  0.525233   | 0.599422    | False         |
# | 69 |             3 | Oceania     | new_accounts / sessions      | new accounts      | sessions    |            47 |           684 |     0.0687135 |            51 |           763 |     0.0668414 |    -0.0272441   |  0.141488   | 0.887484    | False         |
# | 70 |             3 | Americas    | new_accounts / sessions      | new accounts      | sessions    |          3222 |         38689 |     0.0832795 |          3218 |         38992 |     0.0825297 |    -0.00900264  |  0.378913   | 0.704753    | False         |
# | 71 |             3 | (not set)   | new_accounts / sessions      | new accounts      | sessions    |            12 |           175 |     0.0685714 |             9 |           152 |     0.0592105 |    -0.136513    |  0.344399   | 0.730546    | False         |
# | 72 |             4 | Asia        | add_payment_info / sessions  | add_payment_info  | sessions    |           819 |         24908 |     0.032881  |           830 |         25165 |     0.0329823 |     0.00308125  | -0.0635186  | 0.949354    | False         |
# | 73 |             4 | Europe      | add_payment_info / sessions  | add_payment_info  | sessions    |           747 |         19693 |     0.0379323 |           654 |         19528 |     0.0334904 |    -0.117101    |  2.36991    | 0.0177924   | True          |
# | 74 |             4 | Africa      | add_payment_info / sessions  | add_payment_info  | sessions    |            38 |          1096 |     0.0346715 |            39 |          1086 |     0.0359116 |     0.0357662   | -0.156972   | 0.875267    | False         |
# | 75 |             4 | Oceania     | add_payment_info / sessions  | add_payment_info  | sessions    |            75 |          1095 |     0.0684932 |            38 |          1069 |     0.0355472 |    -0.48101     |  3.44432    | 0.000572489 | True          |
# | 76 |             4 | Americas    | add_payment_info / sessions  | add_payment_info  | sessions    |          2030 |         58053 |     0.034968  |          2032 |         58031 |     0.0350158 |     0.0013647   | -0.0442401  | 0.964713    | False         |
# | 77 |             4 | (not set)   | add_payment_info / sessions  | add_payment_info  | sessions    |            22 |           234 |     0.0940171 |             8 |           262 |     0.0305344 |    -0.675226    |  2.96075    | 0.00306892  | True          |
# | 78 |             4 | Asia        | add_shipping_info / sessions | add_shipping_info | sessions    |          1098 |         24908 |     0.0440822 |          1124 |         25165 |     0.0446652 |     0.013225    | -0.316746   | 0.751436    | False         |
# | 79 |             4 | Europe      | add_shipping_info / sessions | add_shipping_info | sessions    |          1055 |         19693 |     0.0535723 |           917 |         19528 |     0.0469582 |    -0.123462    |  2.99713    | 0.00272535  | True          |
# | 80 |             4 | Africa      | add_shipping_info / sessions | add_shipping_info | sessions    |            39 |          1096 |     0.0355839 |            57 |          1086 |     0.0524862 |     0.474996    | -1.92486    | 0.0542468   | False         |
# | 81 |             4 | Oceania     | add_shipping_info / sessions | add_shipping_info | sessions    |            91 |          1095 |     0.083105  |            59 |          1069 |     0.0551918 |    -0.335879    |  2.55599    | 0.0105885   | True          |
# | 82 |             4 | Americas    | add_shipping_info / sessions | add_shipping_info | sessions    |          2818 |         58053 |     0.0485418 |          2785 |         58031 |     0.0479916 |    -0.0113358   |  0.437363   | 0.661848    | False         |
# | 83 |             4 | (not set)   | add_shipping_info / sessions | add_shipping_info | sessions    |            27 |           234 |     0.115385  |            14 |           262 |     0.0534351 |    -0.536896    |  2.50115    | 0.0123791   | True          |
# | 84 |             4 | Asia        | begin_checkout / sessions    | begin_checkout    | sessions    |          2694 |         24908 |     0.108158  |          2764 |         25165 |     0.109835  |     0.0155057   | -0.602092   | 0.547113    | False         |
# | 85 |             4 | Europe      | begin_checkout / sessions    | begin_checkout    | sessions    |          2600 |         19693 |     0.132027  |          2263 |         19528 |     0.115885  |    -0.122261    |  4.84985    | 1.23557e-06 | True          |
# | 86 |             4 | Africa      | begin_checkout / sessions    | begin_checkout    | sessions    |            98 |          1096 |     0.0894161 |           139 |          1086 |     0.127993  |     0.431428    | -2.89559    | 0.00378445  | True          |
# | 87 |             4 | Oceania     | begin_checkout / sessions    | begin_checkout    | sessions    |           218 |          1095 |     0.199087  |           137 |          1069 |     0.128157  |    -0.356275    |  4.4547     | 8.401e-06   | True          |
# | 88 |             4 | Americas    | begin_checkout / sessions    | begin_checkout    | sessions    |          6886 |         58053 |     0.118616  |          6929 |         58031 |     0.119402  |     0.00662603  | -0.413501   | 0.679239    | False         |
# | 89 |             4 | (not set)   | begin_checkout / sessions    | begin_checkout    | sessions    |            59 |           234 |     0.252137  |            35 |           262 |     0.133588  |    -0.470177    |  3.36295    | 0.000771147 | True          |
# | 90 |             4 | Asia        | new_accounts / sessions      | new accounts      | sessions    |          2164 |         24908 |     0.0868797 |          2039 |         25165 |     0.0810252 |    -0.0673861   |  2.36219    | 0.0181675   | True          |
# | 91 |             4 | Europe      | new_accounts / sessions      | new accounts      | sessions    |          1642 |         19693 |     0.0833799 |          1633 |         19528 |     0.0836235 |     0.00292197  | -0.0872069  | 0.930507    | False         |
# | 92 |             4 | Africa      | new_accounts / sessions      | new accounts      | sessions    |            96 |          1096 |     0.0875912 |            74 |          1086 |     0.06814   |    -0.222069    |  1.69495    | 0.0900846   | False         |
# | 93 |             4 | Oceania     | new_accounts / sessions      | new accounts      | sessions    |            77 |          1095 |     0.0703196 |            89 |          1069 |     0.0832554 |     0.183956    | -1.13048    | 0.258273    | False         |
# | 94 |             4 | Americas    | new_accounts / sessions      | new accounts      | sessions    |          4990 |         58053 |     0.0859559 |          4836 |         58031 |     0.0833348 |    -0.0304943   |  1.60418    | 0.108674    | False         |
# | 95 |             4 | (not set)   | new_accounts / sessions      | new accounts      | sessions    |            15 |           234 |     0.0641026 |            16 |           262 |     0.0610687 |    -0.0473282   |  0.139344   | 0.889178    | False         |
# |    |   test_number | device   | metric                       | num_event         | den_event   |   num_count_a |   den_count_a |   conv_rate_a |   num_count_b |   den_count_b |   conv_rate_b |   metric_change |     z_stat |     p_value | significant   |
# |---:|--------------:|:---------|:-----------------------------|:------------------|:------------|--------------:|--------------:|--------------:|--------------:|--------------:|--------------:|----------------:|-----------:|------------:|:--------------|
# |  0 |             1 | desktop  | add_payment_info / sessions  | add_payment_info  | sessions    |          1130 |         26467 |     0.0426947 |          1256 |         26417 |     0.0475451 |     0.113608    | -2.687     | 0.00720974  | True          |
# |  1 |             1 | mobile   | add_payment_info / sessions  | add_payment_info  | sessions    |           810 |         17896 |     0.0452615 |           942 |         17767 |     0.0530196 |     0.171407    | -3.38933   | 0.000700637 | True          |
# |  2 |             1 | tablet   | add_payment_info / sessions  | add_payment_info  | sessions    |            48 |           999 |     0.048048  |            31 |          1009 |     0.0307235 |    -0.360567    |  1.99661   | 0.0458678   | True          |
# |  3 |             1 | desktop  | add_shipping_info / sessions | add_shipping_info | sessions    |          1711 |         26467 |     0.0646465 |          1916 |         26417 |     0.0725291 |     0.121932    | -3.58602   | 0.000335758 | True          |
# |  4 |             1 | mobile   | add_shipping_info / sessions | add_shipping_info | sessions    |          1257 |         17896 |     0.0702392 |          1256 |         17767 |     0.0706929 |     0.00645933  | -0.167387  | 0.867065    | False         |
# |  5 |             1 | tablet   | add_shipping_info / sessions | add_shipping_info | sessions    |            66 |           999 |     0.0660661 |            49 |          1009 |     0.0485629 |    -0.264934    |  1.68773   | 0.091464    | False         |
# |  6 |             1 | desktop  | begin_checkout / sessions    | begin_checkout    | sessions    |          2108 |         26467 |     0.0796464 |          2404 |         26417 |     0.091002  |     0.142576    | -4.67398   | 2.95418e-06 | True          |
# |  7 |             1 | mobile   | begin_checkout / sessions    | begin_checkout    | sessions    |          1593 |         17896 |     0.0890143 |          1561 |         17767 |     0.0878595 |    -0.0129731   |  0.384029  | 0.700957    | False         |
# |  8 |             1 | tablet   | begin_checkout / sessions    | begin_checkout    | sessions    |            83 |           999 |     0.0830831 |            56 |          1009 |     0.0555005 |    -0.331988    |  2.43463   | 0.014907    | True          |
# |  9 |             1 | desktop  | new_accounts / sessions      | new accounts      | sessions    |          2203 |         26467 |     0.0832357 |          2147 |         26417 |     0.0812734 |    -0.0235753   |  0.821212  | 0.411526    | False         |
# | 10 |             1 | mobile   | new_accounts / sessions      | new accounts      | sessions    |          1530 |         17896 |     0.085494  |          1441 |         17767 |     0.0811054 |    -0.0513316   |  1.49949   | 0.133748    | False         |
# | 11 |             1 | tablet   | new_accounts / sessions      | new accounts      | sessions    |            90 |           999 |     0.0900901 |            93 |          1009 |     0.0921705 |     0.0230922   | -0.161955  | 0.871341    | False         |
# | 12 |             2 | desktop  | add_payment_info / sessions  | add_payment_info  | sessions    |          1314 |         29497 |     0.0445469 |          1401 |         29380 |     0.0476855 |     0.070456    | -1.81559   | 0.0694338   | False         |
# | 13 |             2 | mobile   | add_payment_info / sessions  | add_payment_info  | sessions    |           978 |         20017 |     0.0488585 |           961 |         19756 |     0.0486435 |    -0.00440088  |  0.0995617 | 0.920692    | False         |
# | 14 |             2 | tablet   | add_payment_info / sessions  | add_payment_info  | sessions    |            52 |          1123 |     0.0463045 |            47 |          1108 |     0.0424188 |    -0.0839177   |  0.445631  | 0.655864    | False         |
# | 15 |             2 | desktop  | add_shipping_info / sessions | add_shipping_info | sessions    |          1988 |         29497 |     0.0673967 |          2088 |         29380 |     0.0710688 |     0.0544844   | -1.75504   | 0.0792523   | False         |
# | 16 |             2 | mobile   | add_shipping_info / sessions | add_shipping_info | sessions    |          1417 |         20017 |     0.0707898 |          1356 |         19756 |     0.0686374 |    -0.0304062   |  0.842754  | 0.399366    | False         |
# | 17 |             2 | tablet   | add_shipping_info / sessions | add_shipping_info | sessions    |            75 |          1123 |     0.0667854 |            66 |          1108 |     0.0595668 |    -0.108087    |  0.700617  | 0.483542    | False         |
# | 18 |             2 | desktop  | begin_checkout / sessions    | begin_checkout    | sessions    |          2403 |         29497 |     0.0814659 |          2585 |         29380 |     0.087985  |     0.0800226   | -2.84029   | 0.00450724  | True          |
# | 19 |             2 | mobile   | begin_checkout / sessions    | begin_checkout    | sessions    |          1766 |         20017 |     0.088225  |          1656 |         19756 |     0.0838226 |    -0.0498994   |  1.56542   | 0.117484    | False         |
# | 20 |             2 | tablet   | begin_checkout / sessions    | begin_checkout    | sessions    |            93 |          1123 |     0.0828139 |            72 |          1108 |     0.0649819 |    -0.215325    |  1.60917   | 0.10758     | False         |
# | 21 |             2 | desktop  | new_accounts / sessions      | new accounts      | sessions    |          2442 |         29497 |     0.0827881 |          2385 |         29380 |     0.0811777 |    -0.0194522   |  0.712176  | 0.476356    | False         |
# | 22 |             2 | mobile   | new_accounts / sessions      | new accounts      | sessions    |          1623 |         20017 |     0.0810811 |          1701 |         19756 |     0.0861004 |     0.0619052   | -1.80849   | 0.0705298   | False         |
# | 23 |             2 | tablet   | new_accounts / sessions      | new accounts      | sessions    |           100 |          1123 |     0.0890472 |            98 |          1108 |     0.0884477 |    -0.00673285  |  0.0497883 | 0.960291    | False         |
# | 24 |             3 | desktop  | add_payment_info / sessions  | add_payment_info  | sessions    |          2087 |         41106 |     0.0507712 |          2167 |         41443 |     0.0522887 |     0.0298892   | -0.986051  | 0.324108    | False         |
# | 25 |             3 | mobile   | add_payment_info / sessions  | add_payment_info  | sessions    |          1463 |         27404 |     0.0533864 |          1463 |         27423 |     0.0533494 |    -0.000692849 |  0.0192666 | 0.984628    | False         |
# | 26 |             3 | tablet   | add_payment_info / sessions  | add_payment_info  | sessions    |            73 |          1537 |     0.0474951 |            67 |          1573 |     0.0425938 |    -0.103197    |  0.659106  | 0.509828    | False         |
# | 27 |             3 | desktop  | add_shipping_info / sessions | add_shipping_info | sessions    |          3120 |         41106 |     0.0759013 |          3072 |         41443 |     0.0741259 |    -0.0233912   |  0.968268  | 0.332911    | False         |
# | 28 |             3 | mobile   | add_shipping_info / sessions | add_shipping_info | sessions    |          2071 |         27404 |     0.0755729 |          2029 |         27423 |     0.073989  |    -0.0209589   |  0.704992  | 0.480816    | False         |
# | 29 |             3 | tablet   | add_shipping_info / sessions | add_shipping_info | sessions    |           107 |          1537 |     0.0696161 |            87 |          1573 |     0.0553083 |    -0.205524    |  1.64953   | 0.0990393   | False         |
# | 30 |             3 | desktop  | begin_checkout / sessions    | begin_checkout    | sessions    |          5618 |         41106 |     0.136671  |          5567 |         41443 |     0.134329  |    -0.0171358   |  0.983009  | 0.325603    | False         |
# | 31 |             3 | mobile   | begin_checkout / sessions    | begin_checkout    | sessions    |          3735 |         27404 |     0.136294  |          3562 |         27423 |     0.129891  |    -0.0469794   |  2.20693   | 0.0273186   | True          |
# | 32 |             3 | tablet   | begin_checkout / sessions    | begin_checkout    | sessions    |           179 |          1537 |     0.116461  |           135 |          1573 |     0.0858233 |    -0.263071    |  2.8353    | 0.00457822  | True          |
# | 33 |             3 | desktop  | new_accounts / sessions      | new accounts      | sessions    |          3458 |         41106 |     0.084124  |          3409 |         41443 |     0.0822576 |    -0.0221865   |  0.970872  | 0.331612    | False         |
# | 34 |             3 | mobile   | new_accounts / sessions      | new accounts      | sessions    |          2272 |         27404 |     0.0829076 |          2276 |         27423 |     0.082996  |     0.00106649  | -0.0375328 | 0.97006     | False         |
# | 35 |             3 | tablet   | new_accounts / sessions      | new accounts      | sessions    |           126 |          1537 |     0.0819779 |           137 |          1573 |     0.0870947 |     0.0624174   | -0.512758  | 0.608121    | False         |
# | 36 |             4 | desktop  | add_payment_info / sessions  | add_payment_info  | sessions    |          2211 |         61484 |     0.0359606 |          2046 |         61436 |     0.0333029 |    -0.0739039   |  2.54793   | 0.0108363   | True          |
# | 37 |             4 | mobile   | add_payment_info / sessions  | add_payment_info  | sessions    |          1413 |         41216 |     0.0342828 |          1501 |         41345 |     0.0363043 |     0.0589644   | -1.57387   | 0.115517    | False         |
# | 38 |             4 | tablet   | add_payment_info / sessions  | add_payment_info  | sessions    |           107 |          2379 |     0.0449769 |            54 |          2360 |     0.0228814 |    -0.491264    |  4.19807   | 2.69195e-05 | True          |
# | 39 |             4 | desktop  | add_shipping_info / sessions | add_shipping_info | sessions    |          3042 |         61484 |     0.0494763 |          2845 |         61436 |     0.0463084 |    -0.0640293   |  2.60063   | 0.00930527  | True          |
# | 40 |             4 | mobile   | add_shipping_info / sessions | add_shipping_info | sessions    |          1961 |         41216 |     0.0475786 |          2023 |         41345 |     0.0489297 |     0.0283978   | -0.905776  | 0.365054    | False         |
# | 41 |             4 | tablet   | add_shipping_info / sessions | add_shipping_info | sessions    |           125 |          2379 |     0.0525431 |            88 |          2360 |     0.0372881 |    -0.290332    |  2.53431   | 0.0112668   | True          |
# | 42 |             4 | desktop  | begin_checkout / sessions    | begin_checkout    | sessions    |          7456 |         61484 |     0.121267  |          7026 |         61436 |     0.114363  |    -0.0569354   |  3.75427   | 0.000173849 | True          |
# | 43 |             4 | mobile   | begin_checkout / sessions    | begin_checkout    | sessions    |          4788 |         41216 |     0.116168  |          5009 |         41345 |     0.121151  |     0.042893    | -2.21361   | 0.0268555   | True          |
# | 44 |             4 | tablet   | begin_checkout / sessions    | begin_checkout    | sessions    |           311 |          2379 |     0.130727  |           232 |          2360 |     0.0983051 |    -0.248014    |  3.50365   | 0.000458935 | True          |
# | 45 |             4 | desktop  | new_accounts / sessions      | new accounts      | sessions    |          5314 |         61484 |     0.086429  |          5105 |         61436 |     0.0830946 |    -0.0385795   |  2.09859   | 0.0358526   | True          |
# | 46 |             4 | mobile   | new_accounts / sessions      | new accounts      | sessions    |          3455 |         41216 |     0.0838267 |          3384 |         41345 |     0.0818479 |    -0.0236059   |  1.0314    | 0.302353    | False         |
# | 47 |             4 | tablet   | new_accounts / sessions      | new accounts      | sessions    |           215 |          2379 |     0.0903741 |           198 |          2360 |     0.0838983 |    -0.0716555   |  0.790263  | 0.429374    | False         |
# |    |   test_number | channel        | metric                       | num_event         | den_event   |   num_count_a |   den_count_a |   conv_rate_a |   num_count_b |   den_count_b |   conv_rate_b |   metric_change |     z_stat |     p_value | significant   |
# |---:|--------------:|:---------------|:-----------------------------|:------------------|:------------|--------------:|--------------:|--------------:|--------------:|--------------:|--------------:|----------------:|-----------:|------------:|:--------------|
# |  0 |             1 | Organic Search | add_payment_info / sessions  | add_payment_info  | sessions    |           640 |         15675 |     0.0408293 |           514 |         15631 |     0.0328834 |     -0.194614   |  3.73076   | 0.000190905 | True          |
# |  1 |             1 | Undefined      | add_payment_info / sessions  | add_payment_info  | sessions    |           269 |          3336 |     0.0806355 |           416 |          3397 |     0.122461  |      0.518698   | -5.67617   | 1.37747e-08 | True          |
# |  2 |             1 | Direct         | add_payment_info / sessions  | add_payment_info  | sessions    |           392 |         10691 |     0.0366664 |           516 |         10361 |     0.0498021 |      0.358252   | -4.69026   | 2.72857e-06 | True          |
# |  3 |             1 | Paid Search    | add_payment_info / sessions  | add_payment_info  | sessions    |           450 |         11777 |     0.0382101 |           519 |         11841 |     0.0438308 |      0.1471     | -2.17739   | 0.0294515   | True          |
# |  4 |             1 | Social Search  | add_payment_info / sessions  | add_payment_info  | sessions    |           237 |          3883 |     0.0610353 |           264 |          3963 |     0.0666162 |      0.0914376  | -1.01091   | 0.312061    | False         |
# |  5 |             1 | Organic Search | add_shipping_info / sessions | add_shipping_info | sessions    |          1021 |         15675 |     0.0651356 |           922 |         15631 |     0.0589853 |     -0.0944218  |  2.25509   | 0.0241274   | True          |
# |  6 |             1 | Undefined      | add_shipping_info / sessions | add_shipping_info | sessions    |           279 |          3336 |     0.0836331 |           436 |          3397 |     0.128349  |      0.534662   | -5.95448   | 2.60906e-09 | True          |
# |  7 |             1 | Direct         | add_shipping_info / sessions | add_shipping_info | sessions    |           664 |         10691 |     0.0621083 |           716 |         10361 |     0.0691053 |      0.112658   | -2.05071   | 0.0402954   | True          |
# |  8 |             1 | Paid Search    | add_shipping_info / sessions | add_shipping_info | sessions    |           770 |         11777 |     0.0653817 |           794 |         11841 |     0.0670551 |      0.0255954  | -0.517118  | 0.605074    | False         |
# |  9 |             1 | Social Search  | add_shipping_info / sessions | add_shipping_info | sessions    |           300 |          3883 |     0.0772599 |           353 |          3963 |     0.0890739 |      0.152914   | -1.89412   | 0.0582086   | False         |
# | 10 |             1 | Organic Search | begin_checkout / sessions    | begin_checkout    | sessions    |          1249 |         15675 |     0.079681  |          1144 |         15631 |     0.0731879 |     -0.081489   |  2.16196   | 0.0306216   | True          |
# | 11 |             1 | Undefined      | begin_checkout / sessions    | begin_checkout    | sessions    |           353 |          3336 |     0.105815  |           569 |          3397 |     0.167501  |      0.582953   | -7.36133   | 1.82082e-13 | True          |
# | 12 |             1 | Direct         | begin_checkout / sessions    | begin_checkout    | sessions    |           823 |         10691 |     0.0769806 |           915 |         10361 |     0.0883119 |      0.147197   | -2.98659   | 0.00282109  | True          |
# | 13 |             1 | Paid Search    | begin_checkout / sessions    | begin_checkout    | sessions    |           967 |         11777 |     0.0821092 |           958 |         11841 |     0.0809053 |     -0.0146618  |  0.338093  | 0.735293    | False         |
# | 14 |             1 | Social Search  | begin_checkout / sessions    | begin_checkout    | sessions    |           392 |          3883 |     0.100953  |           435 |          3963 |     0.109765  |      0.0872928  | -1.27094   | 0.203748    | False         |
# | 15 |             1 | Organic Search | new_accounts / sessions      | new accounts      | sessions    |          1307 |         15675 |     0.0833812 |          1301 |         15631 |     0.083232  |     -0.00178867 |  0.0477452 | 0.961919    | False         |
# | 16 |             1 | Undefined      | new_accounts / sessions      | new accounts      | sessions    |           301 |          3336 |     0.0902278 |           247 |          3397 |     0.0727112 |     -0.194137   |  2.62818   | 0.00858435  | True          |
# | 17 |             1 | Direct         | new_accounts / sessions      | new accounts      | sessions    |           913 |         10691 |     0.0853989 |           850 |         10361 |     0.0820384 |     -0.0393508  |  0.879999  | 0.37886     | False         |
# | 18 |             1 | Paid Search    | new_accounts / sessions      | new accounts      | sessions    |           990 |         11777 |     0.0840622 |           948 |         11841 |     0.0800608 |     -0.0475999  |  1.1203    | 0.262587    | False         |
# | 19 |             1 | Social Search  | new_accounts / sessions      | new accounts      | sessions    |           312 |          3883 |     0.0803502 |           335 |          3963 |     0.0845319 |      0.0520431  | -0.673259  | 0.500783    | False         |
# | 20 |             2 | Organic Search | add_payment_info / sessions  | add_payment_info  | sessions    |           698 |         17466 |     0.0399634 |           597 |         17428 |     0.0342552 |     -0.142834   |  2.82028   | 0.00479819  | True          |
# | 21 |             2 | Undefined      | add_payment_info / sessions  | add_payment_info  | sessions    |           332 |          3661 |     0.0906856 |           436 |          3670 |     0.118801  |      0.310033   | -3.93032   | 8.48317e-05 | True          |
# | 22 |             2 | Direct         | add_payment_info / sessions  | add_payment_info  | sessions    |           516 |         11820 |     0.0436548 |           504 |         11670 |     0.0431877 |     -0.0107013  |  0.175651  | 0.860568    | False         |
# | 23 |             2 | Paid Search    | add_payment_info / sessions  | add_payment_info  | sessions    |           539 |         13329 |     0.0404381 |           571 |         13187 |     0.0433002 |      0.0707767  | -1.16353   | 0.244615    | False         |
# | 24 |             2 | Social Search  | add_payment_info / sessions  | add_payment_info  | sessions    |           259 |          4361 |     0.05939   |           301 |          4289 |     0.0701795 |      0.181672   | -2.03897   | 0.0414528   | True          |
# | 25 |             2 | Organic Search | add_shipping_info / sessions | add_shipping_info | sessions    |          1130 |         17466 |     0.0646971 |          1040 |         17428 |     0.0596741 |     -0.0776393  |  1.94267   | 0.0520559   | False         |
# | 26 |             2 | Undefined      | add_shipping_info / sessions | add_shipping_info | sessions    |           353 |          3661 |     0.0964217 |           445 |          3670 |     0.121253  |      0.257532   | -3.41321   | 0.000642033 | True          |
# | 27 |             2 | Direct         | add_shipping_info / sessions | add_shipping_info | sessions    |           791 |         11820 |     0.0669205 |           747 |         11670 |     0.0640103 |     -0.0434873  |  0.901554  | 0.367294    | False         |
# | 28 |             2 | Paid Search    | add_shipping_info / sessions | add_shipping_info | sessions    |           842 |         13329 |     0.0631705 |           916 |         13187 |     0.0694623 |      0.0996005  | -2.0589    | 0.039504    | True          |
# | 29 |             2 | Social Search  | add_shipping_info / sessions | add_shipping_info | sessions    |           364 |          4361 |     0.0834671 |           362 |          4289 |     0.084402  |      0.0112004  | -0.156779  | 0.875419    | False         |
# | 30 |             2 | Organic Search | begin_checkout / sessions    | begin_checkout    | sessions    |          1385 |         17466 |     0.0792969 |          1251 |         17428 |     0.071781  |     -0.0947815  |  2.65634   | 0.00789932  | True          |
# | 31 |             2 | Undefined      | begin_checkout / sessions    | begin_checkout    | sessions    |           448 |          3661 |     0.122371  |           561 |          3670 |     0.152861  |      0.249161   | -3.78879   | 0.000151383 | True          |
# | 32 |             2 | Direct         | begin_checkout / sessions    | begin_checkout    | sessions    |           965 |         11820 |     0.0816413 |           937 |         11670 |     0.0802913 |     -0.016535   |  0.379218  | 0.704526    | False         |
# | 33 |             2 | Paid Search    | begin_checkout / sessions    | begin_checkout    | sessions    |          1022 |         13329 |     0.0766749 |          1103 |         13187 |     0.083643  |      0.090878   | -2.08951   | 0.0366622   | True          |
# | 34 |             2 | Social Search  | begin_checkout / sessions    | begin_checkout    | sessions    |           442 |          4361 |     0.101353  |           461 |          4289 |     0.107484  |      0.0604952  | -0.93245   | 0.351104    | False         |
# | 35 |             2 | Organic Search | new_accounts / sessions      | new accounts      | sessions    |          1422 |         17466 |     0.0814153 |          1500 |         17428 |     0.0860684 |      0.0571523  | -1.56896   | 0.116658    | False         |
# | 36 |             2 | Undefined      | new_accounts / sessions      | new accounts      | sessions    |           290 |          3661 |     0.0792133 |           308 |          3670 |     0.0839237 |      0.0594644  | -0.736742  | 0.46128     | False         |
# | 37 |             2 | Direct         | new_accounts / sessions      | new accounts      | sessions    |          1002 |         11820 |     0.0847716 |           966 |         11670 |     0.0827763 |     -0.0235365  |  0.551853  | 0.581049    | False         |
# | 38 |             2 | Paid Search    | new_accounts / sessions      | new accounts      | sessions    |          1084 |         13329 |     0.0813264 |          1074 |         13187 |     0.0814438 |      0.00144375 | -0.0349626 | 0.97211     | False         |
# | 39 |             2 | Social Search  | new_accounts / sessions      | new accounts      | sessions    |           367 |          4361 |     0.084155  |           336 |          4289 |     0.0783399 |     -0.0690995  |  0.989589  | 0.322375    | False         |
# | 40 |             3 | Organic Search | add_payment_info / sessions  | add_payment_info  | sessions    |          1036 |         24585 |     0.0421395 |          1098 |         25055 |     0.0438236 |      0.0399642  | -0.924884  | 0.355026    | False         |
# | 41 |             3 | Undefined      | add_payment_info / sessions  | add_payment_info  | sessions    |           492 |          4636 |     0.106126  |           542 |          4534 |     0.119541  |      0.126409   | -2.03063   | 0.0422925   | True          |
# | 42 |             3 | Direct         | add_payment_info / sessions  | add_payment_info  | sessions    |           861 |         16337 |     0.0527025 |           794 |         16326 |     0.0486341 |     -0.0771952  |  1.67625   | 0.093689    | False         |
# | 43 |             3 | Paid Search    | add_payment_info / sessions  | add_payment_info  | sessions    |           816 |         18763 |     0.0434898 |           831 |         18744 |     0.0443342 |      0.0194146  | -0.399028  | 0.689872    | False         |
# | 44 |             3 | Social Search  | add_payment_info / sessions  | add_payment_info  | sessions    |           418 |          5726 |     0.0730003 |           432 |          5780 |     0.0747405 |      0.0238374  | -0.356803  | 0.72124     | False         |
# | 45 |             3 | Organic Search | add_shipping_info / sessions | add_shipping_info | sessions    |          1601 |         24585 |     0.065121  |          1563 |         25055 |     0.0623828 |     -0.0420487  |  1.24864   | 0.211795    | False         |
# | 46 |             3 | Undefined      | add_shipping_info / sessions | add_shipping_info | sessions    |           587 |          4636 |     0.126618  |           655 |          4534 |     0.144464  |      0.140946   | -2.49691   | 0.0125282   | True          |
# | 47 |             3 | Direct         | add_shipping_info / sessions | add_shipping_info | sessions    |          1233 |         16337 |     0.0754729 |          1154 |         16326 |     0.0706848 |     -0.0634408  |  1.66241   | 0.0964308   | False         |
# | 48 |             3 | Paid Search    | add_shipping_info / sessions | add_shipping_info | sessions    |          1294 |         18763 |     0.0689655 |          1232 |         18744 |     0.0657277 |     -0.0469484  |  1.251     | 0.210934    | False         |
# | 49 |             3 | Social Search  | add_shipping_info / sessions | add_shipping_info | sessions    |           583 |          5726 |     0.101816  |           584 |          5780 |     0.101038  |     -0.00764332 |  0.138254  | 0.89004     | False         |
# | 50 |             3 | Organic Search | begin_checkout / sessions    | begin_checkout    | sessions    |          2921 |         24585 |     0.118812  |          2738 |         25055 |     0.10928   |     -0.0802333  |  3.34127   | 0.000833958 | True          |
# | 51 |             3 | Undefined      | begin_checkout / sessions    | begin_checkout    | sessions    |          1066 |          4636 |     0.22994   |          1175 |          4534 |     0.259153  |      0.127048   | -3.2548    | 0.00113473  | True          |
# | 52 |             3 | Direct         | begin_checkout / sessions    | begin_checkout    | sessions    |          2191 |         16337 |     0.134113  |          2094 |         16326 |     0.128262  |     -0.0436281  |  1.56612   | 0.117321    | False         |
# | 53 |             3 | Paid Search    | begin_checkout / sessions    | begin_checkout    | sessions    |          2322 |         18763 |     0.123754  |          2192 |         18744 |     0.116944  |     -0.0550293  |  2.02675   | 0.0426877   | True          |
# | 54 |             3 | Social Search  | begin_checkout / sessions    | begin_checkout    | sessions    |          1032 |          5726 |     0.180231  |          1065 |          5780 |     0.184256  |      0.0223354  | -0.559247  | 0.575993    | False         |
# | 55 |             3 | Organic Search | new_accounts / sessions      | new accounts      | sessions    |          2084 |         24585 |     0.0847671 |          2067 |         25055 |     0.0824985 |     -0.0267631  |  0.91292   | 0.361285    | False         |
# | 56 |             3 | Undefined      | new_accounts / sessions      | new accounts      | sessions    |           383 |          4636 |     0.0826143 |           363 |          4534 |     0.0800618 |     -0.0308974  |  0.447039  | 0.654847    | False         |
# | 57 |             3 | Direct         | new_accounts / sessions      | new accounts      | sessions    |          1339 |         16337 |     0.0819612 |          1376 |         16326 |     0.0842827 |      0.028325   | -0.759911  | 0.447308    | False         |
# | 58 |             3 | Paid Search    | new_accounts / sessions      | new accounts      | sessions    |          1576 |         18763 |     0.0839951 |          1553 |         18744 |     0.0828532 |     -0.013595   |  0.39988   | 0.689245    | False         |
# | 59 |             3 | Social Search  | new_accounts / sessions      | new accounts      | sessions    |           474 |          5726 |     0.0827803 |           463 |          5780 |     0.0801038 |     -0.0323325  |  0.524845  | 0.599691    | False         |
# | 60 |             4 | Organic Search | add_payment_info / sessions  | add_payment_info  | sessions    |          1092 |         38033 |     0.0287119 |          1063 |         37831 |     0.0280986 |     -0.021359   |  0.508372  | 0.611192    | False         |
# | 61 |             4 | Undefined      | add_payment_info / sessions  | add_payment_info  | sessions    |           496 |          5716 |     0.086774  |           566 |          5862 |     0.0965541 |      0.112708   | -1.82281   | 0.0683318   | False         |
# | 62 |             4 | Direct         | add_payment_info / sessions  | add_payment_info  | sessions    |           893 |         24395 |     0.0366059 |           831 |         24653 |     0.0337079 |     -0.0791676  |  1.74255   | 0.0814128   | False         |
# | 63 |             4 | Paid Search    | add_payment_info / sessions  | add_payment_info  | sessions    |           776 |         28974 |     0.0267826 |           761 |         28739 |     0.0264797 |     -0.0113109  |  0.226004  | 0.821199    | False         |
# | 64 |             4 | Social Search  | add_payment_info / sessions  | add_payment_info  | sessions    |           474 |          7961 |     0.0595403 |           380 |          8056 |     0.0471698 |     -0.207766   |  3.48416   | 0.000493685 | True          |
# | 65 |             4 | Organic Search | add_shipping_info / sessions | add_shipping_info | sessions    |          1558 |         38033 |     0.0409644 |          1437 |         37831 |     0.0379847 |     -0.0727388  |  2.1073    | 0.035092    | True          |
# | 66 |             4 | Undefined      | add_shipping_info / sessions | add_shipping_info | sessions    |           640 |          5716 |     0.111966  |           666 |          5862 |     0.113613  |      0.014707   | -0.280026  | 0.779457    | False         |
# | 67 |             4 | Direct         | add_shipping_info / sessions | add_shipping_info | sessions    |          1191 |         24395 |     0.0488215 |          1150 |         24653 |     0.0466475 |     -0.0445298  |  1.12919   | 0.258818    | False         |
# | 68 |             4 | Paid Search    | add_shipping_info / sessions | add_shipping_info | sessions    |          1152 |         28974 |     0.0397598 |          1173 |         28739 |     0.0408156 |      0.0265553  | -0.644989  | 0.518934    | False         |
# | 69 |             4 | Social Search  | add_shipping_info / sessions | add_shipping_info | sessions    |           587 |          7961 |     0.0737345 |           530 |          8056 |     0.0657895 |     -0.107751   |  1.97382   | 0.0484023   | True          |
# | 70 |             4 | Organic Search | begin_checkout / sessions    | begin_checkout    | sessions    |          3907 |         38033 |     0.102727  |          3577 |         37831 |     0.0945521 |     -0.0795752  |  3.7753    | 0.000159815 | True          |
# | 71 |             4 | Undefined      | begin_checkout / sessions    | begin_checkout    | sessions    |          1578 |          5716 |     0.276067  |          1600 |          5862 |     0.272944  |     -0.0113117  |  0.376454  | 0.706579    | False         |
# | 72 |             4 | Direct         | begin_checkout / sessions    | begin_checkout    | sessions    |          2853 |         24395 |     0.11695   |          2826 |         24653 |     0.114631  |     -0.0198299  |  0.802588  | 0.422213    | False         |
# | 73 |             4 | Paid Search    | begin_checkout / sessions    | begin_checkout    | sessions    |          2779 |         28974 |     0.0959136 |          2946 |         28739 |     0.102509  |      0.068762   | -2.65012   | 0.00804624  | True          |
# | 74 |             4 | Social Search  | begin_checkout / sessions    | begin_checkout    | sessions    |          1438 |          7961 |     0.180631  |          1318 |          8056 |     0.163605  |     -0.0942576  |  2.8544    | 0.00431189  | True          |
# | 75 |             4 | Organic Search | new_accounts / sessions      | new accounts      | sessions    |          3325 |         38033 |     0.0874241 |          3140 |         37831 |     0.0830007 |     -0.0505966  |  2.1818    | 0.0291246   | True          |
# | 76 |             4 | Undefined      | new_accounts / sessions      | new accounts      | sessions    |           484 |          5716 |     0.0846746 |           510 |          5862 |     0.087001  |      0.0274749  | -0.446742  | 0.655061    | False         |
# | 77 |             4 | Direct         | new_accounts / sessions      | new accounts      | sessions    |          2102 |         24395 |     0.0861652 |          1980 |         24653 |     0.0803148 |     -0.0678978  |  2.34534   | 0.01901     | True          |
# | 78 |             4 | Paid Search    | new_accounts / sessions      | new accounts      | sessions    |          2406 |         28974 |     0.08304   |          2404 |         28739 |     0.0836494 |      0.00733899 | -0.264842  | 0.791131    | False         |
# | 79 |             4 | Social Search  | new_accounts / sessions      | new accounts      | sessions    |           667 |          7961 |     0.0837834 |           653 |          8056 |     0.0810576 |     -0.0325344  |  0.627241  | 0.530501    | False         |

# %%
# Connecting Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Changing directory
# %cd /content/drive/MyDrive/MATE/PortfolioProject2
# Out:
# /content/drive/MyDrive/MATE/PortfolioProject2

# %%
# Writing data to CSV files
df_summary_total.to_csv('summary_total.csv', index=False)

df_summary_continent.to_csv('summary_continent.csv', index=False)
df_summary_device.to_csv('summary_device.csv', index=False)
df_summary_channel.to_csv('summary_channel.csv', index=False)

# %%
# Get the current working directory
cwd = os.getcwd()
print(f'The CSV files should be located in: {cwd}')
# Out:
# The CSV files should be located in: /content/drive/MyDrive/MATE/PortfolioProject2

# %% [markdown]
# [Tableau Dashboards](https://public.tableau.com/views/ABtests_17592402492710/Significance?:language=en-GB&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link)
#
# ### Files:
#
# [Summary Total](https://drive.google.com/file/d/1yFxlnlrQ3VCpepZe5--AI33ZHLFvDJKC/view?usp=sharing)
#
# [Summary Channel](https://drive.google.com/file/d/1POggFzWB5YjvYaAIm1VcGkezGDC869jq/view?usp=sharing)
#
# [Summary Device](https://drive.google.com/file/d/1xzk8VVY-iUCwA773bZjD5thYxjrVT2Ie/view?usp=sharing)
#
# [Summary Continent](https://drive.google.com/file/d/1E1luirhm1rotDXhnSe00j5i1AvospMMo/view?usp=sharing)
